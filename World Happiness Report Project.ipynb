# %%
#Importing all the required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Load the dataset
df = pd.read_csv("happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# Display the first few rows from the dataframe
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#Display the last few records from the dataset
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
#To check the shape and columns of the dataset
print("The dimension of the dataset",df.shape)
print("The column headers of the dataset",df.columns)
# Out:
# The dimension of the dataset (158, 12)
# The column headers of the dataset Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Checking the lowest and highest happiness score
print("Lowest Happiness Rate: ",df['Happiness Score'].min())
print("Highest Happiness Rate: ",df['Happiness Score'].max())
# Out:
# Lowest Happiness Rate:  2.839
# Highest Happiness Rate:  7.587

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
print("Total Duplicate Rows Are: ",df.duplicated().sum())
# Out:
# Total Duplicate Rows Are:  0

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Bar chart for Happiness Score
plt.bar(df.index, df['Happiness Score'], color='blue', label='Happiness Score')

# Bar chart for Economy (GDP per Capita)
plt.bar(df.index, df['Economy (GDP per Capita)'], color='green', label='Economy (GDP per Capita)')

# Adding labels and title
plt.xlabel('Economy Rate')
plt.ylabel('Happiness Rate')
plt.title('Happiness Score and Economy (GDP per Capita)')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# -->In the above graph we can clearly notice that, good Economy(GDP per Capita) rate of a country is not a resion to make country happiest or saddest.

# %%
from sklearn.linear_model import LinearRegression

# Assuming you have a DataFrame named df with columns 'Happiness Score' and 'Economy (GDP per Capita)'
# Replace 'df' with the actual name of your DataFrame if different

# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Economy (GDP per Capita)'], df['Happiness Score'], color='blue', alpha=0.5)

# Linear regression
model = LinearRegression()
X = df['Economy (GDP per Capita)'].values.reshape(-1, 1)
y = df['Happiness Score'].values.reshape(-1, 1)
model.fit(X, y)
plt.plot(X, model.predict(X), color='red', linewidth=2)

# Adding labels and title
plt.xlabel('Economy (GDP per Capita)')
plt.ylabel('Happiness Score')
plt.title('Relationship between GDP per Capita and Happiness Score with Regression Line')

# Show plot
plt.show()

# %%
# Create subplots with shared x-axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Happiness Score bars
ax1.bar(df.index, df['Happiness Score'], color='blue', label='Happiness Score')
ax1.set_ylabel('Happiness Score', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create a second y-axis sharing the same x-axis
ax2 = ax1.twinx()
ax2.bar(df.index, df['Standard Error'], color='red', label='Standard Error', alpha=0.5)
ax2.set_ylabel('Standard Error', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Adding labels and title
plt.xlabel('Index')
plt.title('Happiness Score vs Standard Error')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # EDA:

# %%
# Summary statistics
print(df.describe())
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
# Correlation matrix
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# Visualize distributions
sns.pairplot(df, diag_kind='kde')
plt.show()

# %% [markdown]
# # Handle Noise or Outliers:

# %%
from scipy.stats import mstats

# Winsorization to handle outliers
df_winsorized = df.copy()
for column in df_winsorized.columns:
    df_winsorized[column] = mstats.winsorize(df_winsorized[column], limits=[0.05, 0.05])

# Check the summary statistics after winsorization
print(df_winsorized.describe())
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.388443        0.047208
# std         45.173797         1.101757        0.013409
# min          8.000000         3.655000        0.030840
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        151.000000         7.364000        0.080960
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846393    0.995383                  0.632553
# std                    0.383690    0.254202                  0.236686
# min                    0.174170    0.414110                  0.150100
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# # Feature Engg:

# %%
# Feature Engineering
df_winsorized['GDP_Life_Expectancy'] = df_winsorized['Economy (GDP per Capita)'] * df_winsorized['Health (Life Expectancy)']

# Check the updated dataset
print(df_winsorized.head())
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               8            7.364
# 1      Iceland  Western Europe               8            7.364
# 2      Denmark  Western Europe               8            7.364
# 3       Norway  Western Europe               8            7.364
# 4       Canada   North America               8            7.364
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39541  1.31967
# 1         0.04884                   1.30232  1.31967
# 2         0.03328                   1.32548  1.31967
# 3         0.03880                   1.39541  1.31967
# 4         0.03553                   1.32629  1.31967
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.64169                        0.41372
# 1                   0.94579  0.62877                        0.14145
# ...

# %% [markdown]
# # 6. Handle Categorical Data:

# %% [markdown]
# -->Since there are no categorical features in this dataset, there's no need for encoding.

# %% [markdown]
# # 7.Selecting best features:

# %%
from sklearn.ensemble import RandomForestRegressor

# Separate features and target variable
X = df_winsorized.drop(columns=['Happiness Score'])
y = df_winsorized['Happiness Score']

# Check for non-numeric columns
non_numeric_columns = X.select_dtypes(exclude=['float64', 'int64']).columns
print("Non-numeric columns:", non_numeric_columns)

# Convert any non-numeric columns to numeric, if applicable
# For categorical variables, you might need to apply one-hot encoding or label encoding
# For simplicity, let's drop any non-numeric columns for now
X_numeric = X.drop(columns=non_numeric_columns)

# Feature importance using Random Forest
rf = RandomForestRegressor(random_state=42)
rf.fit(X_numeric, y)

feature_importances = pd.Series(rf.feature_importances_, index=X_numeric.columns)
print(feature_importances)
# Out:
# Non-numeric columns: Index(['Country', 'Region'], dtype='object')
# Happiness Rank                   0.998640
# Standard Error                   0.000166
# Economy (GDP per Capita)         0.000151
# Family                           0.000131
# Health (Life Expectancy)         0.000231
# Freedom                          0.000133
# Trust (Government Corruption)    0.000131
# Generosity                       0.000144
# Dystopia Residual                0.000130
# GDP_Life_Expectancy              0.000142
# dtype: float64

# %% [markdown]
# # 8.Handling imbalance:

# %% [markdown]
# -->Since this is a regression problem, we don't need to handle imbalance.

# %% [markdown]
# # 9.Feature Scaling:

# %%
from sklearn.preprocessing import MinMaxScaler

non_numeric_values = df_winsorized.applymap(lambda x: isinstance(x, str)).any()
print("Columns with non-numeric values:", non_numeric_values[non_numeric_values].index)
# Out:
# Columns with non-numeric values: Index(['Country', 'Region'], dtype='object')

# %% [markdown]
# # 10.Model Building:

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_numeric, y, test_size=0.2, random_state=42)

# Feature Scaling
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Model Building
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# # 11.Checking Accuracy:

# %% [markdown]
# -->We'll evaluate the model's performance using Mean Squared Error (MSE) on the test set.

# %%
# Predictions on the test set
y_pred = rf_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 4.019527155237521

# %% [markdown]
# # 12.Prediction:

# %% [markdown]
# -->Now, you can use the trained model to make predictions on new data.

# %%
new_data_point = X_test.iloc[0].values.reshape(1, -1)  # It Takes the first row of the test set as an example
predicted_happiness_score = rf_model.predict(new_data_point)
print("Predicted Happiness Score:", predicted_happiness_score)
# Out:
# Predicted Happiness Score: [3.68095]
